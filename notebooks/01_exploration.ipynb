# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from core.data import load_from_kaggle
#from portfolio.notebooks.data import load_from_kaggle

# %%
dataset_link = "lunthu/gog-com-video-games-dataset" # replace with your dataset link from Kaggle 
destination = "../data/raw"
dataset_name = dataset_link.split("/")[-1]

files = load_from_kaggle(
    dataset_link=dataset_link, 
    destination=destination,
    )

# %%
files

# %%
df = pd.read_csv("/".join(["../data/raw/", dataset_name, files[0]]))
df.head()
# Out:
#    id                developer  publisher  \
# 0   4                 Volition  Interplay
# 1   5                 Volition  Interplay
# 2   6      Shiny Entertainment  Interplay
# 3   7      Shiny Entertainment  Interplay
# 4   8  Reflexive Entertainment  Interplay
#
#                                              gallery video  \
# 0  ['//images-4.gog-statics.com/4e4c85f81ebb0f1a1...   NaN
# 1  ['//images-2.gog-statics.com/1f3d26426fba87f09...   NaN
# 2  ['//images-1.gog-statics.com/1c95f819fe0d6e759...   NaN
# 3  ['//images-3.gog-statics.com/ff4266f81aa88127c...   NaN
# 4  ['//images-4.gog-statics.com/2c52160c1e93776e2...   NaN
#
#   supportedOperatingSystems                                    genres  \
# 0               ['windows']        ['Simulation', 'Combat', 'Sci-fi']
# 1               ['windows']        ['Simulation', 'Combat', 'Sci-fi']
# 2               ['windows']               ['Action', 'TPP', 'Sci-fi']
# ...

# %%
display(
    "Shape",
    df.shape,
    "Description",
    df.describe().round(2),
    "Duplicates",
    df.duplicated().sum(),
)


pd.DataFrame(
    {
        "Data Types": df.dtypes,
        "Missing Values": df.isnull().sum(),
        "Unique Values": df.nunique(),
        "Sample Values": [df[col].sample(3).tolist() for col in df.columns]
    })
# Out:
# 'Shape'
# (10896, 51)
# 'Description'
#                  id  globalReleaseDate   releaseDate    rating      type  \
# count  1.089600e+04       1.039300e+04  1.039300e+04  10896.00  10896.00
# mean   1.564603e+09       1.513312e+09  1.513312e+09     13.76      1.83
# std    3.099326e+08       2.493025e+08  2.493025e+08     18.74      0.92
# min    4.000000e+00       3.155256e+08  3.155256e+08      0.00      1.00
# 25%    1.285202e+09       1.470863e+09  1.470863e+09      0.00      1.00
# 50%    1.522005e+09       1.597698e+09  1.597698e+09      0.00      1.00
# 75%    1.828155e+09       1.668031e+09  1.668031e+09     36.00      3.00
# max    2.146639e+09       1.761167e+09  1.761167e+09     50.00      3.00
#
#        ageLimit    amount  baseAmount  finalAmount  discountPercentage  \
# count  10896.00  10896.00    10896.00     10896.00            10896.00
# mean       3.61      8.87       15.03         8.87               41.24
# ...

# %%
fig, ax = plt.subplots(figsize=(12, 10), dpi=200)

sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", center=0, ax=ax);
